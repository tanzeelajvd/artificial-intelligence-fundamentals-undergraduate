# %% [markdown]
# # CAP 379
#
# # Introduction to the JupyterLab
# ## Install Python and Required Libraries, Create a Simple Script, and Explore Jupyter Notebooks

# %% [markdown]
# ## Author
#
# - **Name**: `Tanzeela Javid Kaloo` | `Assistant Professor`
# - **Department**: Systems and Architecture
# - **University**: Lovely Professional University
# - **Email**: tanzeela.jvd@gmail.com

# %% [markdown]
# ## Step 1: Installing Required Libraries
#
# - **Objective:** Install the essential Python libraries to work with data manipulation and visualization.
# - **Details:** Libraries like NumPy, Pandas, Matplotlib, and Seaborn are crucial for numerical operations, data handling, and creating graphs. Use the command `pip install` followed by the library name to install them in your Python environment.

# %%
# pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.9 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.9 MB 1.0 MB/s eta 0:00:12
#    - -------------------------------------- 0.5/12.9 MB 1.0 MB/s eta 0:00:12
#    -- ------------------------------------- 0.8/12.9 MB 1.0 MB/s eta 0:00:12
#    -- ------------------------------------- 0.8/12.9 MB 1.0 MB/s eta 0:00:12
#    -- ------------------------------------- 0.8/12.9 MB 1.0 MB/s eta 0:00:12
#    --- ------------------------------------ 1.0/12.9 MB 709.1 kB/s eta 0:00:17
#    ---- ----------------------------------- 1.3/12.9 MB 745.8 kB/s eta 0:00:16
#    ---- ----------------------------------- 1.3/12.9 MB 745.8 kB/s eta 0:00:16
#    ---- ----------------------------------- 1.3/12.9 MB 745.8 kB/s eta 0:00:16
#    ---- ----------------------------------- 1.6/12.9 MB 655.4 kB/s eta 0:00:18
# ...

# %%
# Install necessary libraries
# !pip install numpy pandas matplotlib seaborn
# Out:
# ERROR: Could not find a version that satisfies the requirement numpy (from versions: none)
# ERROR: No matching distribution found for numpy

# %%
import numpy

# %% [markdown]
# ## Step 2: Import Libraries and Verify Installation
#
# - **Objective:** Verify that the libraries are correctly installed and ready to use.
# - **Details:** Import the libraries (`NumPy`, `Pandas`, `Matplotlib`, `Seaborn`) and check their installed versions. This ensures the installation was successful and compatible with your Python version.

# %%
# Import required libraries
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Verify installation
print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("Matplotlib version:", plt.matplotlib.__version__)
print("Seaborn version:", sns.__version__)
# Out:
# NumPy version: 2.1.3
# Pandas version: 2.2.3
# Matplotlib version: 3.9.2
# Seaborn version: 0.13.2

# %% [markdown]
# ## Step 3: Create a Simple Python Script for Data Manipulation

# %%
# Create a sample dataset
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [24, 27, 22, 32, 29],
    'Score': [85, 90, 88, 92, 95]
}
data
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
#  'Age': [24, 27, 22, 32, 29],
#  'Score': [85, 90, 88, 92, 95]}

# %%
# Convert to DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print("Initial Dataset:")
print(df)
# Out:
# Initial Dataset:
#       Name  Age  Score
# 0    Alice   24     85
# 1      Bob   27     90
# 2  Charlie   22     88
# 3    David   32     92
# 4      Eva   29     95

# %%
# Perform basic data manipulation
# Add a new column with grades
def assign_grade(score):
    if score >= 90:
        return 'A'
    elif score >= 80:
        return 'B'
    else:
        return 'C'

df['Grade'] = df['Score'].apply(assign_grade)

# %%
print("\nDataset After Adding Grades:")
print(df)
# Out:
# Dataset After Adding Grades:
#       Name  Age  Score Grade
# 0    Alice   24     85     B
# 1      Bob   27     90     A
# 2  Charlie   22     88     B
# 3    David   32     92     A
# 4      Eva   29     95     A

# %%
df
# Out:
#       Name  Age  Score Grade
# 0    Alice   24     85     B
# 1      Bob   27     90     A
# 2  Charlie   22     88     B
# 3    David   32     92     A
# 4      Eva   29     95     A

# %% [markdown]
# ## Step 4: Data Visualization
#
# - **Objective:** Use data visualization techniques to extract insights from the dataset.

# %%
# Plot the distribution of ages
plt.figure(figsize=(8, 5))
sns.histplot(df['Age'], bins=5, kde=True, color='blue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot scores by name
plt.figure(figsize=(8, 5))
sns.barplot(x='Name', y='Score', data=df, palette='viridis')
plt.title('Scores by Name')
plt.xlabel('Name')
plt.ylabel('Score')
plt.show()
# Out:
# C:\Users\TJ\AppData\Local\Temp\ipykernel_16148\4172232917.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Name', y='Score', data=df, palette='viridis')

# %% [markdown]
# ## Step 5: Exploring Jupyter Notebooks
#
# - **Objective:** Familiarize yourself with the interactive capabilities of Jupyter Notebooks

# %% [markdown]
# ### Instructions

# %% [raw]
# 1. Open this file in Jupyter Lab or Jupyter Notebook.
# 2. Run each cell sequentially to observe the output.
# 3. Modify the dataset or visualizations to explore further.
# 4. Use Markdown cells to document your observations.

# %% [markdown]
# ### Markdown Example

# %% [markdown]
# # Experiment Observations
# 1. The data manipulation successfully added grades to the dataset based on scores.
# 2. The visualizations provide insights into the distribution of ages and the scores of each individual.
# 3. Interactive coding in Jupyter Notebooks makes it easy to test and observe changes.
